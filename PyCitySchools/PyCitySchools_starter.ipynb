# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
total_number_schools= school_data['school_name'].count()
total_number_schools
# Out:
# 15

# %%
#total number of students
total_students= student_data['Student ID'].count()
total_students
# Out:
# 39170

# %%
#Calculate the total budget
total_budget= school_data['budget'].sum()
total_budget
# Out:
# 24649428

# %%
#Calculate the average math score (mean)
average_math_score = school_data_complete['math_score'].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
#Calculate the average reading score
average_reading_score = school_data_complete['reading_score'].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
student_data['passing math'] =student_data['math_score']>=70
passing_math_percentage =student_data['passing math'].mean()*100
passing_math_percentage
# Out:
# 74.9808526933878

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)
student_data['reading score'] =student_data['reading_score']>=70
passing_reading_percentage =student_data['reading score'].mean()*100
passing_reading_percentage
# Out:
# 85.80546336482001

# %%
#Calculate the percentage of students who passed math and reading (% Overall Passing)
overall_passing_percentage =(passing_math_percentage + passing_reading_percentage)/2
overall_passing_percentage
# Out:
# 80.39315802910392

# %%
#Create a dataframe to hold the above results
district_summary_table = pd.DataFrame({"Total Number of Schools": [total_number_schools], 
            "Total Number of Students": [total_students], 
            "Total Budget": [total_budget], 
            "Average Math Score": [average_math_score], 
            "Average Reading Score": [average_reading_score], 
           "% Students with Passing Math Scores": [passing_math_percentage],
           "% Students with Passing Reading Scores": [passing_reading_percentage],
            "% Students Passing both Subjects": [overall_passing_percentage]})

#Optional: give the displayed data cleaner formatting

#round off to two decimal places
district_summary_table["Average Math Score"]=round(average_math_score,2)
district_summary_table["Average Reading Score"]=round(average_reading_score,2)
district_summary_table["% Students with Passing Math Scores"]=round(passing_math_percentage,2)
district_summary_table["% Students with Passing Reading Scores"]=round(passing_reading_percentage,2)

#add percentage sign to the required fields
district_summary_table["% Students with Passing Math Scores"] = district_summary_table["% Students with Passing Math Scores"].map("{:,.2f}%".format)
district_summary_table["% Students with Passing Reading Scores"] = district_summary_table["% Students with Passing Reading Scores"].map("{:,.2f}%".format)
district_summary_table["% Students Passing both Subjects"] = district_summary_table["% Students Passing both Subjects"].map("{:,.2f}%".format)

#add dollar sign for total budget
district_summary_table["Total Budget"] = district_summary_table["Total Budget"].map("${:,.2f}".format)

district_summary_table
# Out:
#    Total Number of Schools  Total Number of Students    Total Budget  \
# 0                       15                     39170  $24,649,428.00
#
#    Average Math Score  Average Reading Score  \
# 0               78.99                  81.88
#
#   % Students with Passing Math Scores % Students with Passing Reading Scores  \
# 0                              74.98%                                 85.81%
#
#   % Students Passing both Subjects
# 0                           80.39%

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_data_complete["passing_math"] = school_data_complete["math_score"] >= 70
school_data_complete["read_score"] = school_data_complete["reading_score"] >= 70

school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
school_name = school_data_complete.school_name.sort_values().unique()
school_name
# Out:
# array(['Bailey High School', 'Cabrera High School',
#        'Figueroa High School', 'Ford High School', 'Griffin High School',
#        'Hernandez High School', 'Holden High School', 'Huang High School',
#        'Johnson High School', 'Pena High School', 'Rodriguez High School',
#        'Shelton High School', 'Thomas High School', 'Wilson High School',
#        'Wright High School'], dtype=object)

# %%
#school name (another way of confirming the school name)
school_name=school_data['school_name']
school_name
# Out:
# 0         Huang High School
# 1      Figueroa High School
# 2       Shelton High School
# 3     Hernandez High School
# 4       Griffin High School
# 5        Wilson High School
# 6       Cabrera High School
# 7        Bailey High School
# 8        Holden High School
# 9          Pena High School
# 10       Wright High School
# 11    Rodriguez High School
# 12      Johnson High School
# 13         Ford High School
# 14       Thomas High School
# Name: school_name, dtype: object

# %%
#school type along school name
school_types=school_data.set_index(["school_name"])["type"]
school_types
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
#Total Students per school
total_students=school_data_complete['school_name'].value_counts()
total_students
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
#Total School Budget
#use groupby and mean to calculate the total budget
school_budget= school_data_complete.groupby(["school_name"])["budget"].mean()
school_budget
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
#Per Student Budget (we need to divide the school budget by total number of students in eash school)
per_student_budget=(school_budget/total_students)
per_student_budget
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#Average Math Score per school
average_math_score= school_data_complete.groupby(["school_name"])['math_score'].mean()
average_math_score
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#Average Reading Score per school
average_reading_score= school_data_complete.groupby(["school_name"])["reading_score"].mean()
average_reading_score
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
#% Passing Math

passing_math_score=school_data_complete.loc[school_data_complete["math_score"]>=70]
passing_math_score

#assign the math score by each school
group_math_per_school= passing_math_score["school_name"].value_counts()
group_math_per_school

percent_math= (group_math_per_school/total_students)*100
percent_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: school_name, dtype: float64

# %%
#% Passing Reading
passing_reading_score=school_data_complete.loc[school_data_complete['reading_score']>=70]
passing_reading_score

#assign the reading score by each school
reading_per_school= passing_reading_score['school_name'].value_counts()
reading_per_school

percent_reading= (reading_per_school/total_students)*100
percent_reading
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: school_name, dtype: float64

# %%
#% Overall Passing (The percentage of students that passed math and reading.)

overall_passing = (percent_math+ percent_reading)/ 2
overall_passing
# Out:
# Bailey High School       74.306672
# Cabrera High School      95.586652
# Figueroa High School     73.363852
# Ford High School         73.804308
# Griffin High School      95.265668
# Hernandez High School    73.807983
# Holden High School       94.379391
# Huang High School        73.500171
# Johnson High School      73.639992
# Pena High School         95.270270
# Rodriguez High School    73.293323
# Shelton High School      94.860875
# Thomas High School       95.290520
# Wilson High School       95.203679
# Wright High School       94.972222
# Name: school_name, dtype: float64

# %%
#Create a dataframe to hold the above results
school_summary = pd.DataFrame({"School Type": school_types,
                               "Total Students" : total_students,
                               "Total School Budget": school_budget,
                               "Per Student Budget":per_student_budget, 
                               "Average Math Score": average_math_score,
                               "Average Reading Score": average_reading_score, 
                               "% Passing Math": percent_math,
                               "% Passing Reading": percent_reading,
                               "% Overall Passing Rate": overall_passing})

#round off to two decimal places
school_summary["Average Math Score"]=round(average_math_score,2)
school_summary["Average Reading Score"]=round(average_reading_score,2)
school_summary["% Passing Math"]=round(percent_math,2)
school_summary["% Passing Reading"]=round(percent_reading,2)
school_summary["% Overall Passing Rate"]=round(overall_passing,2)

#Optional: give the displayed data cleaner formatting
#add dollar sign to total school budget and per student budget
school_summary["Total School Budget"] = school_summary["Total School Budget"].map("${:,.2f}".format)
school_summary["Per Student Budget"] = school_summary["Per Student Budget"].map("${:,.2f}".format)

#display table
school_summary
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_five_schools = school_summary.sort_values(["% Overall Passing Rate"], ascending=False)

top_five_schools.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Pena High School        Charter             962         $585,858.00
# Wilson High School      Charter            2283       $1,319,574.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00               83.06
# Thomas High School             $638.00               83.42
# Griffin High School            $625.00               83.35
# Pena High School               $609.00               83.84
# Wilson High School             $578.00               83.27
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School                  83.98           94.13              97.04
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_five_schools = school_summary.sort_values(["% Overall Passing Rate"], ascending=True)
bottom_five_schools.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Ford High School         District            2739       $1,763,916.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00               76.84
# Figueroa High School             $639.00               76.71
# Huang High School                $655.00               76.63
# Johnson High School              $650.00               77.07
# Ford High School                 $644.00               77.10
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School                  80.74           66.37
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Create data series of scores by grade levels using conditionals
grade_9th = school_data_complete[(school_data_complete["grade"] == "9th")]
grade_10th = school_data_complete[(school_data_complete["grade"] == "10th")]
grade_11th = school_data_complete[(school_data_complete["grade"] == "11th")]
grade_12th = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group each by school name and math score
grade_9th_scores = grade_9th.groupby(["school_name"]).mean()["math_score"]
grade_10th_scores = grade_10th.groupby(["school_name"]).mean()["math_score"]
grade_11th_scores = grade_11th.groupby(["school_name"]).mean()["math_score"]
grade_12th_scores = grade_12th.groupby(["school_name"]).mean()["math_score"]

# Combine series into single data frame
math_scores_by_grade = pd.DataFrame({"9th": grade_9th_scores, "10th": grade_10th_scores,
                                "11th": grade_11th_scores, "12th": grade_12th_scores})


# Display the results
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %%
# Create data series of scores by grade levels using conditionals
grade_9th = school_data_complete[(school_data_complete["grade"] == "9th")]
grade_10th = school_data_complete[(school_data_complete["grade"] == "10th")]
grade_11th = school_data_complete[(school_data_complete["grade"] == "11th")]
grade_12th = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group each by school name
grade_9th_scores = grade_9th.groupby(["school_name"]).mean()["reading_score"]
grade_10th_scores = grade_10th.groupby(["school_name"]).mean()["reading_score"]
grade_11th_scores = grade_11th.groupby(["school_name"]).mean()["reading_score"]
grade_12th_scores = grade_12th.groupby(["school_name"]).mean()["reading_score"]

# Combine series into single data frame
reading_scores_by_grade = pd.DataFrame({"9th": grade_9th_scores, "10th": grade_10th_scores,
                                "11th": grade_11th_scores, "12th": grade_12th_scores})


# Display the results
reading_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#sample bins  (establish the bins)
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"] #labels


# Categorize the spending based on the bins
school_summary["Spending Ranges (Per Student)"] = pd.cut(per_student_budget, spending_bins, labels=group_names)

spending_math_scores = school_summary.groupby(["Spending Ranges (Per Student)"]).mean()["Average Math Score"]
spending_reading_scores = school_summary.groupby(["Spending Ranges (Per Student)"]).mean()["Average Reading Score"]
spending_passing_math = school_summary.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Math"]
spending_passing_reading = school_summary.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Reading"]
overall_passing_spending = school_summary.groupby(["Spending Ranges (Per Student)"]).mean()["% Overall Passing Rate"]

overall_passing_rate = (spending_passing_math + spending_passing_reading) /2

#assign into a data frame
spending_summary = pd.DataFrame({"Average Math Score" : spending_math_scores,
                                 "Average Reading Score": spending_reading_scores,
                                 "% Passing Math": spending_passing_math,
                                 "% Passing Reading": spending_passing_reading,
                                 "% Overall Passing Rate": overall_passing_rate})


# Display results
spending_summary
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.452500              83.935000
# $585-615                                83.600000              83.885000
# $615-645                                79.078333              81.891667
# $645-675                                76.996667              81.026667
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460000          96.610000
# $585-615                            94.230000          95.900000
# $615-645                            75.668333          86.106667
# $645-675                            66.163333          81.133333
#
#                                % Overall Passing Rate
# Spending Ranges (Per Student)
# <$585                                       95.035000
# $585-615                                    95.065000
# ...

# %% [raw]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
#Sample bins (establishing the bins)
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# Categorize the spending based on the bins
school_summary["School Size"] = pd.cut(school_summary["Total Students"], size_bins, labels=group_names)

# Calculate the scores based on bins
size_math_scores = school_summary.groupby(["School Size"]).mean()["Average Math Score"]
size_reading_scores = school_summary.groupby(["School Size"]).mean()["Average Reading Score"]
size_passing_math = school_summary.groupby(["School Size"]).mean()["% Passing Math"]
size_passing_reading = school_summary.groupby(["School Size"]).mean()["% Passing Reading"]
overall_passing_rate = (size_passing_math + size_passing_reading) / 2

# assign it into a data frame
size_summary = pd.DataFrame({"Average Math Score" : size_math_scores,
                             "Average Reading Score": size_reading_scores,
                             "% Passing Math": size_passing_math,
                             "% Passing Reading": size_passing_reading,
                             "% Overall Passing Rate": overall_passing_rate})


# Display results
size_summary
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                   83.820               83.92500        93.55000
# Medium (1000-2000)              83.374               83.86800        93.59800
# Large (2000-5000)               77.745               81.34375        69.96375
#
#                     % Passing Reading  % Overall Passing Rate
# School Size
# Small (<1000)                96.10000                  94.825
# Medium (1000-2000)           96.79000                  95.194
# Large (2000-5000)            82.76625                  76.365

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
#Perform the same operations as above, based on school type 

type_math_scores = school_summary.groupby(["School Type"]).mean()["Average Math Score"]
type_reading_scores = school_summary.groupby(["School Type"]).mean()["Average Reading Score"]
type_passing_math = school_summary.groupby(["School Type"]).mean()["% Passing Math"]
type_passing_reading = school_summary.groupby(["School Type"]).mean()["% Passing Reading"]
overall_passing_rate = (type_passing_math + type_passing_reading) / 2

# assign into a data frame
type_summary = pd.DataFrame({"Average Math Score" : type_math_scores,
                             "Average Reading Score": type_reading_scores,
                             "% Passing Math": type_passing_math,
                             "% Passing Reading": type_passing_reading,
                             "% Overall Passing Rate": overall_passing_rate})


# Display results
type_summary
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.472500              83.897500       93.620000
# District              76.955714              80.965714       66.548571
#
#              % Passing Reading  % Overall Passing Rate
# School Type
# Charter              96.586250               95.103125
# District             80.798571               73.673571

# %%
#analysis:

# from top 5 schools analysis report, we can see all the top
# schools are charter schools. Among the charter schools we can
# see the Cabrera high school has the highest overall passing rate of 96% and second highest budget 
# while Wilson High school has the highest budget and almost similar passing rate of 95%. 
# however, we can see the total number of students per each school is different and despite having the
# highest budget, Wilson high school still have a higher number of students and almost similar outcomes. 
# has a direct impact on overall passing rate as well. 
# Both these schools have a very close results as well. 

# We can also see all the top 5 bottom schools are feom District school. 
# total number of students and total budget are all higher in bottom
# five schools than the top 5 charter schools. we can conclude that
# school size and total budget does have an impact on overall passing rate. 

# Higher spending per student does not mean a higher overall passing rate. 
# we can see the spending summary and can analyze the %overall passing rate for 
# students with spending amount lower than $585 is the highest 95%. While the highest budget spent
#per student is by Huang High School with total budget of $655 and still comes in top bottom schools with
# 73% overall passing rate. 



#Draws two correct conclusions or comparisons from the calculations:

#Conclusion 1: Overall Charter school performance is much better than district school.
#The Charter overall passing rate is 95% while district school is 73%.

#Conclusion 2: Passing math score is relatively lower than reading score in both schools. 
#Specially percentage of students passing math in District school is way lower than their reading score.
#there are some limitations to look into this data since many other informations are missing such as student skills, 
#teachers, activities, student backgrounds, educational levels, etc.

# we can also look at the spending score by school and conclude that there is not necessarily any a correlation 
# between school spending and average math or reading scores.
